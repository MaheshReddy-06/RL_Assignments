# %% [markdown]
# <a href="https://colab.research.google.com/github/MaheshReddy-06/RL_Assignments/blob/main/RL_Assignment6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q "gymnasium[toy-text]"
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.1/12.1 MB 91.3 MB/s eta 0:00:00

# %%
import gymnasium as gym

# %%
def random_agent(env_name, episodes=10):

    env = gym.make(env_name)

    rewards = []

    print("Environment:", env_name)
    print("-" * 40)

    for episode in range(1, episodes + 1):

        state, info = env.reset()

        total_reward = 0
        terminated = False
        truncated = False

        while not (terminated or truncated):

            action = env.action_space.sample()

            next_state, reward, terminated, truncated, info = env.step(action)

            total_reward += reward
            state = next_state

        rewards.append(total_reward)

        print("Episode", episode, "Total Reward:", total_reward)

    average_reward = sum(rewards) / len(rewards)

    print("-" * 40)
    print("Average Reward:", average_reward)

    env.close()

# %%
random_agent("CliffWalking-v1", 10)
# Out:
# Environment: CliffWalking-v1
# ----------------------------------------
# Episode 1 Total Reward: -10595
# Episode 2 Total Reward: -124414
# Episode 3 Total Reward: -97794
# Episode 4 Total Reward: -2116
# Episode 5 Total Reward: -15078
# Episode 6 Total Reward: -86914
# Episode 7 Total Reward: -9395
# Episode 8 Total Reward: -9276
# Episode 9 Total Reward: -141331
# Episode 10 Total Reward: -57730
# ----------------------------------------
# Average Reward: -55464.3

# %%
random_agent("Taxi-v4", 10)
# Out:
# Environment: Taxi-v4
# ----------------------------------------
# Episode 1 Total Reward: -695
# Episode 2 Total Reward: -281
# Episode 3 Total Reward: -785
# Episode 4 Total Reward: -767
# Episode 5 Total Reward: -695
# Episode 6 Total Reward: -677
# Episode 7 Total Reward: -567
# Episode 8 Total Reward: -749
# Episode 9 Total Reward: -785
# Episode 10 Total Reward: -848
# ----------------------------------------
# Average Reward: -684.9
